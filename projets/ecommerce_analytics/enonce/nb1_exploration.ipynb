# %% [markdown]
# # E-Commerce Analytics 360
# ## Étape 1 — Contexte métier & exploration des données
#
# > **Avant de commencer** : assure-toi d'avoir lu le contexte, le brief métier et la réflexion stratégique sur la plateforme.
#
# | | |
# |---|---|
# | **Niveau** | Intermédiaire |
# | **Outils** | Python — pandas, matplotlib |
# | **Durée estimée** | 2h à 3h |

# %% [markdown]
# ---
# ## 0. Mise en place de l'environnement

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

import os
import sys

# Détecter si on est dans Colab ou en local
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    SAVE_PATH = "/content/drive/MyDrive/DataProjectLab/projects/ecommerce_analytics/"
else:
    SAVE_PATH = "./outputs/"

# Chemin pour enregistrer les fichiers exportés
os.makedirs(SAVE_PATH, exist_ok=True)
print(f" Environnement Colab : {'Colab' if IN_COLAB else 'Local'}")
print(f" Dossier de travail : {SAVE_PATH}")

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 50)

print("Environnement prêt ✅")
# Out:
# Environnement prêt ✅

# %% [markdown]
# ---
# ## 1. Chargement des données
#
# Les fichiers sont disponibles dans le dossier `data/` du projet.
#
# > 💡 Rappel des fichiers disponibles : `customers.csv`, `products.csv`, `orders.csv`, `order_items.csv`, `reviews.csv`, `web_logs.csv`, `social_media.csv`

# %%
BASE_URL = "https://raw.githubusercontent.com/dataprojectlabs/DataProjectLab-projects/main/projets/ecommerce_analytics/data/"

# À compléter
#customers     = pd.read_csv(BASE_URL + "customers.csv")
# products     = pd.read_csv(BASE_URL + "products.csv")
# orders       = pd.read_csv(BASE_URL + "orders.csv",       parse_dates=["order_date"])
# order_items  = pd.read_csv(BASE_URL + "order_items.csv")
# reviews      = pd.read_csv(BASE_URL + "reviews.csv",      parse_dates=["review_date"])
# web_logs     = pd.read_csv(BASE_URL + "web_logs.csv",     parse_dates=["timestamp"])
# social_media = pd.read_csv(BASE_URL + "social_media.csv", parse_dates=["date"])

# %% [markdown]
# ---
# ## 2. Exploration rapide des tables
#
# Pour chaque table, réponds aux questions suivantes :
# - Que représente cette table ?
# - Quel est son niveau de granularité ?
# - Quelles colonnes seront utiles pour les analyses futures ?

# %%
# Clients
# customers.head()
# customers.info()

# %%
# Produits
# products.head()
# products.info()

# %%
# Commandes
# orders.head()
# orders.info()

# %%
# order_items, reviews, web_logs, social_media
# À compléter

# %% [markdown]
# ---
# ## 3. Relations entre les tables
#
# Identifie les clés de jointure : `customer_id`, `order_id`, `product_id`
#
# **Questions de réflexion :**
# - Quelle table porte l'information client ?
# - Quelle table permet de détailler le contenu d'une commande ?
# - Comment relier un avis client à un produit ?

# %%
# Volumes par table
# print(f"Clients    : {customers['customer_id'].nunique():,}")
# print(f"Commandes  : {orders['order_id'].nunique():,}")
# print(f"Produits   : {products['product_id'].nunique():,}")
# print(f"Lignes cmd : {len(order_items):,}")

# %% [markdown]
# ---
# ## 4. Premiers KPIs
#
# Construis une première vue business avec :
# - CA total
# - Nombre de commandes
# - Panier moyen
# - Évolution mensuelle du CA
# - Top 5 catégories
# - Répartition des commandes par canal

# %%
# Merge de base
# df = order_items.merge(orders, on="order_id").merge(products, on="product_id")

# %%
# KPIs principaux
# ca_total      = ...
# nb_commandes  = ...
# panier_moyen  = ...

# %%
# Évolution mensuelle du CA
# À compléter

# %%
# Top 5 catégories + répartition par canal
# À compléter

# %% [markdown]
# ---
# ## 5. Checklist de validation
#
# Avant de passer à l'étape suivante, vérifie que tu as :
#
# - [ ] Toutes les tables chargées sans erreur
# - [ ] Compris la granularité de chaque table
# - [ ] Identifié les clés de jointure
# - [ ] Calculé les 3 KPIs principaux
# - [ ] Produit l'évolution mensuelle du CA
# - [ ] Rédigé au moins 3 observations business

# %% [markdown]
# ---
# ## 6. Observations business
#
# > Rédige ici tes constats en langage métier, pas technique.
# > Exemple : *"Le canal X représente Y% des commandes mais seulement Z% du CA, ce qui suggère..."*

# %% [markdown]
# *(À compléter)*

# %% [markdown]
# ---
#
# **DataProjectLab** — apprendre la data sur des cas concrets, structurés et orientés métier.
